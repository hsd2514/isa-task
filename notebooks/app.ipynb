# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("../data/Uncleaned_employees_final_dataset (1).csv")

# %%
df
# Out:
#        employee_id         department     region  education gender  \
# 0             8724         Technology  region_26  Bachelors      m
# 1            74430                 HR   region_4  Bachelors      f
# 2            72255  Sales & Marketing  region_13  Bachelors      m
# 3            38562        Procurement   region_2  Bachelors      f
# 4            64486            Finance  region_29  Bachelors      m
# ...            ...                ...        ...        ...    ...
# 17412        64573         Technology   region_7  Bachelors      f
# 17413        49584                 HR   region_7  Bachelors      m
# 17414        49584                 HR   region_7  Bachelors      m
# 17415        49584                 HR   region_7  Bachelors      m
# 17416        64573                 HR   region_7  Bachelors      f
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0                sourcing                1   24                   NaN
# ...

# %%
df.dropna()
# Out:
#        employee_id         department     region  education gender  \
# 1            74430                 HR   region_4  Bachelors      f
# 2            72255  Sales & Marketing  region_13  Bachelors      m
# 3            38562        Procurement   region_2  Bachelors      f
# 4            64486            Finance  region_29  Bachelors      m
# 5            46232        Procurement   region_7  Bachelors      m
# ...            ...                ...        ...        ...    ...
# 17412        64573         Technology   region_7  Bachelors      f
# 17413        49584                 HR   region_7  Bachelors      m
# 17414        49584                 HR   region_7  Bachelors      m
# 17415        49584                 HR   region_7  Bachelors      m
# 17416        64573                 HR   region_7  Bachelors      f
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 1                   other                1   31                   3.0
# ...

# %%
X=df.drop("avg_training_score",axis=1)
y=df["avg_training_score"]

# %%
# Out:
# <17417x17560 sparse matrix of type '<class 'numpy.float64'>'
# 	with 209004 stored elements in Compressed Sparse Row format>

# %%
import joblib
en_model = joblib.load('../models/EnsembleModel.pkl')
en_model.fit(transformed_data, y)
# Out:
# [Voting] .... (1 of 2) Processing RandomForestRegressor, total=  30.9s
# [Voting] ......... (2 of 2) Processing XGBoostRegressor, total=   0.5s
# VotingRegressor(estimators=[('RandomForestRegressor',
#                              RandomForestRegressor(max_depth=10,
#                                                    min_samples_split=10,
#                                                    n_estimators=400)),
#                             ('XGBoostRegressor',
#                              XGBRegressor(base_score=None, booster='gbtree',
#                                           callbacks=None,
#                                           colsample_bylevel=None,
#                                           colsample_bynode=None,
#                                           colsample_bytree=1, device=None,
#                                           early_stopping_rounds=None,
#                                           enable_categorical=False,
# ...

# %%
import pandas as pd

df=pd.read_csv("../data/Uncleaned_employees_final_dataset (1).csv")

df.iloc[2]
# Out:
# employee_id                          72255
# department               Sales & Marketing
# region                           region_13
# education                        Bachelors
# gender                                   m
# recruitment_channel                  other
# no_of_trainings                          1
# age                                     31
# previous_year_rating                   1.0
# length_of_service                        4
# KPIs_met_more_than_80                    0
# awards_won                               0
# avg_training_score                      47
# Name: 2, dtype: object

# %%
import joblib 
en_model = joblib.load('../models/EnsembleModelScaled.pkl')
ohenc = joblib.load('../models/ohe.pkl')
scaler = joblib.load('../models/scaler.pkl')
lebal_encoder = joblib.load('../models/label_encoder.pkl')

test=df.drop("avg_training_score",axis=1).iloc[2].to_frame()
test=test.T
test
# Out:
#   employee_id         department     region  education gender  \
# 2       72255  Sales & Marketing  region_13  Bachelors      m
#
#   recruitment_channel no_of_trainings age previous_year_rating  \
# 2               other               1  31                  1.0
#
#   length_of_service KPIs_met_more_than_80 awards_won
# 2                 4                     0          0

# %%
ohenc_test = ohenc.transform(test)

# %%
ohenc_test
# Out:
# <1x15565 sparse matrix of type '<class 'numpy.float64'>'
# 	with 12 stored elements in Compressed Sparse Row format>

# %%
#lets train standard scaler
scaler_test = scaler.transform(ohenc_test)

# %%
en_model.predict(scaler_test)
# Out:
# array([59.42684038])

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder

pipeline = Pipeline([
    ('encoder', joblib.load('../models/ohe.pkl')),
    ('scaler', joblib.load('../models/scaler.pkl')),
    ('model', joblib.load('../models/EnsembleModelScaled.pkl'))
])

# %%
test2=df.drop("avg_training_score",axis=1).iloc[4].to_frame()

# %%
df.iloc[4]
# Out:
# employee_id                  64486
# department                 Finance
# region                   region_29
# education                Bachelors
# gender                           m
# recruitment_channel       sourcing
# no_of_trainings                  1
# age                             30
# previous_year_rating           4.0
# length_of_service                7
# KPIs_met_more_than_80            0
# awards_won                       0
# avg_training_score              61
# Name: 4, dtype: object

# %%
pipeline.predict(test2.T)
# Out:
# array([64.55154885])

# %%
#lets export the pipeline
import joblib
joblib.dump(pipeline, '../models/pipelineV1.joblib')
# Out:
# ['../models/pipelineV1.joblib']
